# %% [markdown]
# * 데이터 시각화를 할 때 유용한 방법중 하나가 데이터 집단들을 서로의 옆에 위치시켜 비교가 용이하도록 하는 것
# * ggplot2에서는 x 위치나 색깔, 모양 등 에스테틱에 이산 변수를 대입하는 방법이 있음
# * 또 다른 방법으로 트렐리스(Trellis) 표현 방법이 있음
# * 패셋(facet)이라는 칭함

# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.4.4"

# %% [markdown]
# 수직으로 정렬한 하위 패널에 drv를 기준으로 면을 분할

# %%
ggplot(mpg, aes(x=displ, y=hwy)) + geom_point() + facet_grid(drv ~ .)
# Out:
# plot without title

# %% [markdown]
# 수평으로 정렬한 하위 패널에 drv를 기준으로 면을 분할

# %%
ggplot(mpg, aes(x=displ, y=hwy)) + geom_point() + facet_grid(. ~ drv )
# Out:
# plot without title

# %% [markdown]
# drv(수직)와 cyl(수평)을 동시에 분할

# %%
ggplot(mpg, aes(x=displ, y=hwy)) + geom_point() + facet_grid(drv ~ cyl)
# Out:
# plot without title

# %% [markdown]
# facet_wrap()을 사용하면 페이지에 단어들이 들어가는 식으로 하위 그래프들이 수평으로 나열된다.

# %%
ggplot(mpg, aes(x=displ, y=hwy)) + geom_point() + facet_wrap( ~ class)
# Out:
# plot without title

# %%
ggplot(mpg, aes(x=displ, y=hwy)) + geom_point() + facet_wrap( ~ class, nrow=2)
# Out:
# plot without title

# %%
ggplot(mpg, aes(x=displ, y=hwy)) + geom_point() + facet_wrap( ~ class, nrow=4)
# Out:
# plot without title

# %% [markdown]
# ## 다른

# %%
p <- ggplot(mpg, aes(x=displ, y=hwy)) + geom_point()

# %% [markdown]
# y축 눈금을 자유롭게

# %%
p + facet_grid(drv ~ cyl, scales = "free_y")
# Out:
# plot without title

# %%
p + facet_grid(drv ~ cyl, scales = "free_x")
# Out:
# plot without title

# %%
p + facet_grid(drv ~ cyl, scales = "free")
# Out:
# plot without title

# %% [markdown]
# # 분할 면 라벨의 텍스트 변경하기

# %%
mpg2 <- mpg

# %%
mpg2$drv <- as.factor(mpg2$drv)

# %%
levels(mpg2$drv)=="4"
# Out:
# [1]  TRUE FALSE FALSE

# %%
# 4를 4wd로, f를 Front로, r을 Rear로 이름을 바꾼다.
levels(mpg2$drv)[levels(mpg2$drv)=="4"] <- "4wd"
levels(mpg2$drv)[levels(mpg2$drv)=="f"] <- "Front"
levels(mpg2$drv)[levels(mpg2$drv)=="r"] <- "Rear"

# %%
mpg2$drv
# Out:
#   [1] Front Front Front Front Front Front Front 4wd   4wd   4wd   4wd   4wd
#  [13] 4wd   4wd   4wd   4wd   4wd   4wd   Rear  Rear  Rear  Rear  Rear  Rear
#  [25] Rear  Rear  Rear  Rear  4wd   4wd   4wd   4wd   Front Front Front Front
#  [37] Front Front Front Front Front Front Front Front Front Front Front Front
#  [49] 4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd
#  [61] 4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd
#  [73] 4wd   4wd   Rear  Rear  Rear  4wd   4wd   4wd   4wd   4wd   4wd   4wd
#  [85] 4wd   4wd   4wd   4wd   4wd   4wd   Rear  Rear  Rear  Rear  Rear  Rear
#  [97] Rear  Rear  Rear  Front Front Front Front Front Front Front Front Front
# [109] Front Front Front Front Front Front Front Front Front Front Front Front
# [121] Front Front 4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd
# [133] 4wd   4wd   Rear  Rear  Rear  4wd   4wd   4wd   4wd   Front Front Front
# [145] Front Front Front Front Front Front 4wd   4wd   4wd   4wd   Front Front
# [157] Front Front Front 4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd
# [169] 4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   4wd   Front
# [181] Front Front Front Front Front Front Front Front Front Front Front Front
# [193] Front Front Front Front Front Front 4wd   4wd   4wd   4wd   4wd   4wd
# [205] 4wd   4wd   4wd   Front Front Front Front Front Front Front Front Front
# [217] Front Front Front Front Front Front Front Front Front Front Front Front
# [229] Front Front Front Front Front Front
# Levels: 4wd Front Rear

# %%
ggplot(mpg2, aes(x=displ, y=hwy)) + geom_point() + facet_grid(drv ~ .)
# Out:
# plot without title
